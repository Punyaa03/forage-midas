# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/hospital_communication_energy_system.csv")
df
# Out:
#              Timestamp Patient ID  Temperature (°C)  Humidity (%)  \
# 0     01-01-2025 00:00      P0001         35.959197     53.116400
# 1     01-01-2025 00:05      P0002         36.591216     55.613547
# 2     01-01-2025 00:10      P0003         36.462011     58.424429
# 3     01-01-2025 00:15      P0004         36.410249     49.649295
# 4     01-01-2025 00:20      P0005         36.258128     42.872100
# ...                ...        ...               ...           ...
# 9995  04-02-2025 16:55      P9996         36.486313     52.617065
# 9996  04-02-2025 17:00      P9997         37.011693     65.133106
# 9997  04-02-2025 17:05      P9998         36.407790     54.272084
# 9998  04-02-2025 17:10      P9999         36.757020     57.859780
# 9999  04-02-2025 17:15     P10000         37.052674     47.213165
#
#       Oxygen Level (%)  Heart Rate (bpm) Blood Pressure (mmHg)  \
# 0            98.863328                76             (111, 84)
# ...

# %%
df['Heart Rate (bpm)'].mean()
# Out:
# np.float64(79.4136)

# %%
df['Heart Rate (bpm)'].median()
# Out:
# 79.0

# %%
df['Heart Rate (bpm)'].mode()
# Out:
# 0    60
# Name: Heart Rate (bpm), dtype: int64

# %%
df['Heart Rate (bpm)'].var()
# Out:
# 133.2598610260959

# %%
df['Heart Rate (bpm)'].std()
# Out:
# 11.543823501167017

# %%
data={
  "heartrate":[14,34,23,34,56,14,15,56,60]
}
df1=pd.DataFrame(data)
df1
df1["heartrate"].mode()
# Out:
# 0    14
# 1    34
# 2    56
# Name: heartrate, dtype: int64
